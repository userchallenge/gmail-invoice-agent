# %% [markdown]
# # Database Query Notebook
#
# This notebook provides a scratchpad for querying the email processing database with Pandas.

# %%
import pandas as pd
import sys
import os

# Add the project root to Python path
sys.path.append(os.getcwd())

from email_processing.database.db_manager import EmailDatabaseManager

# %%
# Initialize database manager
db_manager = EmailDatabaseManager()
connection = db_manager.get_connection()

print(f"Connected to database: {db_manager.db_path}")
# Out:
# Connected to database: data/email_processing.db

# %%
import textwrap

pd.set_option("display.max_colwidth", None)
# Fetch all emails from the emails table
query = "SELECT * FROM categorizations"
categorizations_df = pd.read_sql(query, connection)


# def wrap_column(categorizations_df, col, width=80):
#     categorizations_df[col] = categorizations_df[col].apply(
#         lambda x: "\n".join(textwrap.wrap(str(x), width))
#     )
#     return categorizations_df


# # Usage:
# categorizations_df = wrap_column(categorizations_df, "ai_reasoning", width=80)


print(f"Fetched {len(categorizations_df)} categorizations from database")
categorizations_df.sort_values(by="created_at", ascending=True)[
    ["email_id", "ai_reasoning"]
].head(20)
# Out:
# Fetched 30 categorizations from database
#             email_id  \
# 0   1990bb498a57e609
# 1   1990bb44ffd9e8bc
# 2   1990b78f53342fe3
# 3   1990b4558397f0b4
# 4   1990b1a132ca27f0
# 5   1990b180383e7498
# 6   1990af6275cda803
# 7   1990aee2541f2915
# 8   1990aca8c0a2ad1c
# 9   1990ab7d6d290b51
# 10  1990ab638a16eb90
# 11  1990aabe3b75242f
# 12  1990a8f4b7af9b33
# 13  1990a859fd71266f
# 14  1990a7ba8d20fa25
# 15  1990a529b9c49232
# 16  1990a3daccdac2c3
# 17  1990a3a5afbbf56d
# 18  1990a38ec225b039
# 19  1990a0093a32b84e
#
#                                                                                                                                                                                                                                                                              ai_reasoning
# 0                                                                This is a security alert from Netflix about a new device login. It requires action to verify if the login was authorized and suggests changing the password if it wasn't, making it an actionable security notification.
# 1                                                                                        This is a newsletter email from Tim Ferriss containing updates about his latest podcast episode and weekly content. It's purely informational and doesn't require any action from the recipient.
# 2   This is a security alert email from GitHub about Dependabot vulnerability warnings that require attention and updates. Multiple dependencies need to be upgraded to address security vulnerabilities, including high severity issues, which demands action from the repository owner.
# 3                                                              This is a shipping notification email from Temu informing about order delivery status. It's an automated message containing tracking information and standard policy links, requiring no direct action from the recipient.
# 4                                                                                                       This is a promotional email from LinkedIn notifying about job openings. It's an automated notification about job market trends and doesn't require any action from the recipient.
# 5                                                          This is a notification email from H&M about terms and conditions update ('Uppdatering av villkor'). It contains links to view the email in browser and unsubscribe options, typical of informational marketing communications.
# 6                                                            This is clearly a promotional email about a clearance sale ("Lagerrensning") and lighting week discount offer (15% off) from a retailer. It's a marketing communication that requires no specific action from the recipient.
# 7                                                                                      This is a promotional newsletter from Elite Hotels Rewards advertising hotel discounts and weekend offers. It's purely informational marketing content with no required action from the recipient.
# 8                                                                              This is clearly a newsletter email from GAFFA Sweden, containing subscription information and unsubscribe options. It's purely informational content with no required actions except optional unsubscribe.
# 9                                                                                     This appears to be an automated notification email from SEB bank regarding a customer application. No-reply sender addresses typically indicate informational updates rather than requiring action.
# 10                                                                                         This is a payment confirmation email from Qliro for a purchase at Bangerhead.se. It's purely informational, notifying the customer that their payment was successful, with no action required.
# 11                                                                                                                 This is a LinkedIn job recommendation email containing automated job listings. It's informational content that doesn't require any specific action from the recipient.
# 12     This appears to be an automated notification email from a corporate onboarding system (SEB bank), likely confirming receipt of a business customer application. The no-reply email address suggests it's an automated informational message rather than requiring specific action.
# 13                  This is a notification email from Gjensidige Insurance informing the recipient that they have received a new message in their customer portal. It's purely informational and doesn't require immediate action - the user can check their portal at their convenience.
# 14                                                                              This is an automated order status notification from Temu informing about a package being transferred to DHL for delivery. It's a transactional update that doesn't require any action from the recipient.
# 15                                                                        This is a promotional email from Adidas advertising new products (Teamgeist & Adilenium 4.0). It contains multiple marketing links and is purely informational without requiring any action from the recipient.
# 16                                                                                This is an automated LinkedIn job alert notification showing new job matches. It's purely informational, providing updates about job listings without requiring any specific action from the recipient.
# 17                                             This is a marketing email forwarded through a domain registrar's contact system. It's an unsolicited advertisement for logo and website design services, requiring no immediate action unless the recipient is interested in the services.
# 18                                                                                                                                    This is a login authentication email containing a secure sign-in link that requires user action to complete the login process to Anthropic Console.
# 19                       This is an automated notification email from Ework Verama showing new job listings. It's purely informational, providing updates about available positions, and doesn't require any specific action from the recipient beyond optional browsing of the listings.

# %%
# Fetch all emails from the emails table
query = "SELECT * FROM emails"
emails_df = pd.read_sql(query, connection)

print(f"Fetched {len(emails_df)} emails from database")
emails_df.sort_values(by="date", ascending=True)
# Out:
# Fetched 30 emails from database
#             email_id                        date  \
# 25  19903f72de38e2cf  2025-09-01 00:26:54.000000
# 29  199039fb3156b42b  2025-09-01 04:53:41.000000
# 28  19903aea85a240ee  2025-09-01 05:10:00.000000
# 27  19903c86c586ae2a  2025-09-01 05:38:10.000000
# 26  19903e49f272c89c  2025-09-01 06:08:57.000000
# 24  1990415001c36374  2025-09-01 07:01:49.000000
# 8   1990563a309aa3db  2025-09-01 07:06:50.000000
# 23  19904199cf7d9364  2025-09-01 07:06:51.000000
# 22  199042c12eaee11c  2025-09-01 07:27:00.000000
# 21  1990444cdb4e3b38  2025-09-01 07:53:57.000000
# 20  199044a73f3b6888  2025-09-01 08:00:11.000000
# 18  199047f59a69613b  2025-09-01 08:53:27.000000
# 17  1990485923541ca2  2025-09-01 09:04:46.000000
# 16  19904a99ea2a2f52  2025-09-01 09:44:07.000000
# 19  199044e44e36281b  2025-09-01 10:04:17.000000
# 15  19904c6d18139556  2025-09-01 10:16:01.000000
# 14  19904d94a9b6ce45  2025-09-01 10:36:13.000000
# 13  19904f582d6ada5a  2025-09-01 11:07:02.000000
# 12  19904ffac52f171c  2025-09-01 11:18:08.000000
# 11  19904ffad35e7649  2025-09-01 11:18:08.000000
# 10  1990528955c2f6f1  2025-09-01 12:02:49.000000
# 9   19905375a32ca2f6  2025-09-01 12:18:57.000000
# 6   199057debc442032  2025-09-01 13:36:01.000000
# 5   19905b2e4a67baf4  2025-09-01 14:33:53.000000
# 4   19905b37508a2710  2025-09-01 14:34:31.000000
# 3   19905b74fd461892  2025-09-01 14:38:41.000000
# 7   199056d9bf6edd0d  2025-09-01 15:18:13.000000
# 2   19905d37200caffc  2025-09-01 17:09:15.000000
# 1   19906993906421e1  2025-09-01 18:45:22.000000
# 0   1990702e17ffcf78  2025-09-01 20:40:52.000000
#
#                                                sender  \
# 25                     Willys <willys@kund.willys.se>
# 29     Billy Oppenheimer <billy@billyoppenheimer.com>
# 28           Medium Daily Digest <noreply@medium.com>
# 27                 Nordnet <no-reply@mail.nordnet.se>
# 26                      "Hitta.se" <noreply@hitta.se>
# 24            Kivra <noreply@notifications.kivra.com>
# 8     Live Nation - Sweden <email@info.livenation.se>
# 23                 "IMDb.com" <do-not-reply@imdb.com>
# 22  Amazon Web Services <aws-marketing-email-repli...
# 21  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 20                        Holdit <friends@holdit.com>
# 18                        Temu <temu@orders.temu.com>
# 17              LinkedIn <jobs-listings@linkedin.com>
# 16  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 19               OLKA Sportresor <nyhetsbrev@olka.se>
# 15                      TLDR <dan@tldrnewsletter.com>
# 14  Ework Verama Notification <no-reply.verama@ewo...
# 13  "Svenska Golfförbundet" <no-reply@mingolfutski...
# 12           GolfStar Sverige <no-reply@sweetspot.io>
# 11                              no-reply@sweetspot.io
# 10                    Colby <colby@percentbetter.com>
# 9   "Svenska Golfförbundet" <no-reply@mingolfutski...
# 6                         Temu <temu@orders.temu.com>
# 5                     GAFFA Sweden <noreply@gaffa.se>
# 4                            Lovable <hi@lovable.dev>
# 3                    Autosport <news@e.autosport.com>
# 7       GANT <no-reply@message.digitalrecruiters.com>
# 2                        Magnus Hoem <magnus@hoem.se>
# 1               Google <no-reply@accounts.google.com>
# 0                  Garmin <alerts@account.garmin.com>
#
#                                               subject  \
# 25         Varsågod, veckans Willys Plus-erbjudanden!
# 29  SIX at 6: Swing Your Swing, The Incorrect Way ...
# 28             Claude Code + SubAgents | Gabriel Sena
# 27                Experternas 7 favoritaktier just nu
# 26  Verifiera Wahlström Eriksson, Christin kostnad...
# 24  Ny faktura från Parkman i Sverige AB — betala ...
# 8                   💥 DEF LEPPARD TILL DALHALLA 2026!
# 23                  See what's streaming in September
# 22  Watch sessions on-demand | AWS Summit Stockhol...
# 21  “project manager”: Ingersoll Rand - Senior IT ...
# 20                        Coming soon – Cleo x Holdit
# 18  christian.wahlstrom, meddela oss om du fick detta
# 17  Companies like Forefront Amplify and others in...
# 16  “consultant”: Influence Tech AB - Tech Managem...
# 19   Upplev Champions League från läktarplats 2025/26
# 15  xAI dev steals secrets 👨‍💻, inside Anduril 🚁, ...
# 14                 New jobs published in your country
# 13                 Din nya handicap 01 september 2025
# 12              Bokningsbekräftelse: GolfStar Sverige
# 11                                             Kvitto
# 10  1% Better: A List of 100 Organization Hacks, Y...
# 9              Registrerad HCP-rond 01 september 2025
# 6                       Ditt temu-konto är nu aktivt!
# 5                 Vi listar Bob hunds tio bästa låtar
# 4   Lovable Update - student discount, security ce...
# 3   Why the drivers' title battle is becoming F1's...
# 7                       We received your application!
# 2                               I morgon är det dags!
# 1      Säkerhetsvarning för wahlstrom.kalle@gmail.com
# 0                 Action Required: Download Your Data
#
#                                         body_markdown  \
# 25  Varsagod, veckans Willys Plus-erbjudanden!  ͏ ...
# 29  96 ​ ​ ***************************************...
# 28  Stories for Christian Wahlström @christian.wah...
# 27  1 september Visa i webbläsare (\nhttp://track....
# 26  Gör det enkelt för kunderna att välja er med e...
# 24  |  |  |   \n---  \n  \n|  |   \n---  \n  \n# N...
# 8   https://view.mailing.livenation.com/?qs=ceaa6f...
# 23  IMDb Streaming Guides Check out our watch guid...
# 22  The keynote and 6 sessions are available to wa...
# 21  Your job alert for project manager in Greater ...
# 20  https://holdit.com/ [Nyheter](https://holdit.c...
# 18                                               \n\n
# 17  Hiring in your network Explore relevant jobs t...
# 16  Your job alert for consultant in Greater Stock...
# 19  Lottningen är klar – boka din plats till höste...
# 15  xAI has accused a former employee, Xuechen Li,...
# 14  Hi Christian, 7 new jobs from your country jus...
# 13  |  |  |  |   \n---  \n|  \n---  \n|  |  | \n\n...
# 12  |  \n---  \n  \n|  Hej Christian  \n---  \nDin...
# 11  |  |  |     \n---  \n  \n## Kvitto  \n  \n|  |...
# 10  ​ ​ ​ By Colby Kultgen\n**********************...
# 9   |  |  |  |   \n---  \n|  \n---  \n|  |  | \n\n...
# 6   \---------------------------------------------...
# 5   Hej, Du har fått ett nyhetsbrev från GAFFA Swe...
# 4   Lovable Logo ****************** Lovable Update...
# 3   https://www.autosport.com/ [All Series](https:...
# 7                                                \n\n
# 2   Hej! Här kommer en liten påminnelse om morgond...
# 1   Det här är en kopia av en säkerhetsvarning som...
# 0   |  |  |  |  |  Data Export Request Complete   ...
#
#                                            body_clean pdf_text  \
# 25  Varsagod, veckans Willys Plus-erbjudanden!  ͏ ...
# 29  96 ​ ​ ***************************************...
# 28  Stories for Christian Wahlström @christian.wah...
# 27  1 september Visa i webbläsare (\nhttp://track....
# 26  Gör det enkelt för kunderna att välja er med e...
# 24  |  |  |\n---\n|  |\n---\n# Ny faktura från Par...
# 8   https://view.mailing.livenation.com/?qs=ceaa6f...
# 23  IMDb Streaming Guides Check out our watch guid...
# 22  The keynote and 6 sessions are available to wa...
# 21  Your job alert for project manager in Greater ...
# 20  https://holdit.com/ [Nyheter](https://holdit.c...
# 18
# 17  Hiring in your network Explore relevant jobs t...
# 16  Your job alert for consultant in Greater Stock...
# 19  Lottningen är klar – boka din plats till höste...
# 15  xAI has accused a former employee, Xuechen Li,...
# 14  Hi Christian, 7 new jobs from your country jus...
# 13  |  |  |  |\n---\n|\n---\n|  |  |\n#  Handicapr...
# 12  |\n---\n|  Hej Christian\n---\nDin bokning på ...
# 11  |  |  |\n---\n## Kvitto\n|  |  **Transaktionsd...
# 10  ​ ​ ​ By Colby Kultgen\n**********************...
# 9   |  |  |  |\n---\n|\n---\n|  |  |\n#  Registrer...
# 6   \---------------------------------------------...
# 5   Hej, Du har fått ett nyhetsbrev från GAFFA Swe...
# 4   Lovable Logo ****************** Lovable Update...
# 3   https://www.autosport.com/ [All Series](https:...
# 7
# 2   Hej! Här kommer en liten påminnelse om morgond...
# 1   Det här är en kopia av en säkerhetsvarning som...
# 0   |  |  |  |  |  Data Export Request Complete   ...
#
#                                             raw_email category_id
# 25  {"id": "19903f72de38e2cf", "subject": "Vars\u0...        None
# 29  {"id": "199039fb3156b42b", "subject": "SIX at ...        None
# 28  {"id": "19903aea85a240ee", "subject": "Claude ...        None
# 27  {"id": "19903c86c586ae2a", "subject": "Experte...        None
# 26  {"id": "19903e49f272c89c", "subject": "Verifie...        None
# 24  {"id": "1990415001c36374", "subject": "Ny fakt...        None
# 8   {"id": "1990563a309aa3db", "subject": "\ud83d\...        None
# 23  {"id": "19904199cf7d9364", "subject": "See wha...        None
# 22  {"id": "199042c12eaee11c", "subject": "Watch s...        None
# 21  {"id": "1990444cdb4e3b38", "subject": "\u201cp...        None
# 20  {"id": "199044a73f3b6888", "subject": "Coming ...        None
# 18  {"id": "199047f59a69613b", "subject": "christi...        None
# 17  {"id": "1990485923541ca2", "subject": "Compani...        None
# 16  {"id": "19904a99ea2a2f52", "subject": "\u201cc...        None
# 19  {"id": "199044e44e36281b", "subject": "Upplev ...        None
# 15  {"id": "19904c6d18139556", "subject": "xAI dev...        None
# 14  {"id": "19904d94a9b6ce45", "subject": "New job...        None
# 13  {"id": "19904f582d6ada5a", "subject": "Din nya...        None
# 12  {"id": "19904ffac52f171c", "subject": "Bokning...        None
# 11  {"id": "19904ffad35e7649", "subject": "Kvitto"...        None
# 10  {"id": "1990528955c2f6f1", "subject": "1% Bett...        None
# 9   {"id": "19905375a32ca2f6", "subject": "Registr...        None
# 6   {"id": "199057debc442032", "subject": "Ditt te...        None
# 5   {"id": "19905b2e4a67baf4", "subject": "Vi list...        None
# 4   {"id": "19905b37508a2710", "subject": "Lovable...        None
# 3   {"id": "19905b74fd461892", "subject": "Why the...        None
# 7   {"id": "199056d9bf6edd0d", "subject": "We rece...        None
# 2   {"id": "19905d37200caffc", "subject": "I morgo...        None
# 1   {"id": "19906993906421e1", "subject": "S\u00e4...        None
# 0   {"id": "1990702e17ffcf78", "subject": "Action ...        None

# %%
mask = emails_df["date"] > "2023-01-01"
emails_df[mask][["date", "sender", "subject", "body_clean"]].head(20)
# Out:
#                           date  \
# 0   2025-09-01 20:40:52.000000
# 1   2025-09-01 18:45:22.000000
# 2   2025-09-01 17:09:15.000000
# 3   2025-09-01 14:38:41.000000
# 4   2025-09-01 14:34:31.000000
# 5   2025-09-01 14:33:53.000000
# 6   2025-09-01 13:36:01.000000
# 7   2025-09-01 15:18:13.000000
# 8   2025-09-01 07:06:50.000000
# 9   2025-09-01 12:18:57.000000
# 10  2025-09-01 12:02:49.000000
# 11  2025-09-01 11:18:08.000000
# 12  2025-09-01 11:18:08.000000
# 13  2025-09-01 11:07:02.000000
# 14  2025-09-01 10:36:13.000000
# 15  2025-09-01 10:16:01.000000
# 16  2025-09-01 09:44:07.000000
# 17  2025-09-01 09:04:46.000000
# 18  2025-09-01 08:53:27.000000
# 19  2025-09-01 10:04:17.000000
#
#                                                sender  \
# 0                  Garmin <alerts@account.garmin.com>
# 1               Google <no-reply@accounts.google.com>
# 2                        Magnus Hoem <magnus@hoem.se>
# 3                    Autosport <news@e.autosport.com>
# 4                            Lovable <hi@lovable.dev>
# 5                     GAFFA Sweden <noreply@gaffa.se>
# 6                         Temu <temu@orders.temu.com>
# 7       GANT <no-reply@message.digitalrecruiters.com>
# 8     Live Nation - Sweden <email@info.livenation.se>
# 9   "Svenska Golfförbundet" <no-reply@mingolfutski...
# 10                    Colby <colby@percentbetter.com>
# 11                              no-reply@sweetspot.io
# 12           GolfStar Sverige <no-reply@sweetspot.io>
# 13  "Svenska Golfförbundet" <no-reply@mingolfutski...
# 14  Ework Verama Notification <no-reply.verama@ewo...
# 15                      TLDR <dan@tldrnewsletter.com>
# 16  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 17              LinkedIn <jobs-listings@linkedin.com>
# 18                        Temu <temu@orders.temu.com>
# 19               OLKA Sportresor <nyhetsbrev@olka.se>
#
#                                               subject  \
# 0                 Action Required: Download Your Data
# 1      Säkerhetsvarning för wahlstrom.kalle@gmail.com
# 2                               I morgon är det dags!
# 3   Why the drivers' title battle is becoming F1's...
# 4   Lovable Update - student discount, security ce...
# 5                 Vi listar Bob hunds tio bästa låtar
# 6                       Ditt temu-konto är nu aktivt!
# 7                       We received your application!
# 8                   💥 DEF LEPPARD TILL DALHALLA 2026!
# 9              Registrerad HCP-rond 01 september 2025
# 10  1% Better: A List of 100 Organization Hacks, Y...
# 11                                             Kvitto
# 12              Bokningsbekräftelse: GolfStar Sverige
# 13                 Din nya handicap 01 september 2025
# 14                 New jobs published in your country
# 15  xAI dev steals secrets 👨‍💻, inside Anduril 🚁, ...
# 16  “consultant”: Influence Tech AB - Tech Managem...
# 17  Companies like Forefront Amplify and others in...
# 18  christian.wahlstrom, meddela oss om du fick detta
# 19   Upplev Champions League från läktarplats 2025/26
#
#                                            body_clean
# 0   |  |  |  |  |  Data Export Request Complete   ...
# 1   Det här är en kopia av en säkerhetsvarning som...
# 2   Hej! Här kommer en liten påminnelse om morgond...
# 3   https://www.autosport.com/ [All Series](https:...
# 4   Lovable Logo ****************** Lovable Update...
# 5   Hej, Du har fått ett nyhetsbrev från GAFFA Swe...
# 6   \---------------------------------------------...
# 7
# 8   https://view.mailing.livenation.com/?qs=ceaa6f...
# 9   |  |  |  |\n---\n|\n---\n|  |  |\n#  Registrer...
# 10  ​ ​ ​ By Colby Kultgen\n**********************...
# 11  |  |  |\n---\n## Kvitto\n|  |  **Transaktionsd...
# 12  |\n---\n|  Hej Christian\n---\nDin bokning på ...
# 13  |  |  |  |\n---\n|\n---\n|  |  |\n#  Handicapr...
# 14  Hi Christian, 7 new jobs from your country jus...
# 15  xAI has accused a former employee, Xuechen Li,...
# 16  Your job alert for consultant in Greater Stock...
# 17  Hiring in your network Explore relevant jobs t...
# 18
# 19  Lottningen är klar – boka din plats till höste...

# %%
# Example: Query specific columns only
query = "SELECT email_id, sender, subject, date FROM emails"
emails_summary_df = pd.read_sql(query, connection)

print("Email Summary:")
emails_summary_df.head()
# Out:
# Email Summary:
#            email_id                                        sender  \
# 0  194a8aefa4f1a8cb              Autosport <news@e.autosport.com>
# 1  194a81de444c5c2d  "Kjell & Company" <noreply@medlem.kjell.com>
# 2  194a81d483db0c3b          Ben Thompson <email@stratechery.com>
# 3  194a8095607c6b96           Dropbox <no-reply@em-s.dropbox.com>
# 4  194a7e7f3dde141d  "Kjell & Company" <noreply@medlem.kjell.com>
#
#                                              subject  \
# 0       Newey expects F1 2026 to be engine-dominated
# 1                    Din order har skickats! 9639607
# 2       DeepSeek FAQ (Stratechery Article 1-27-2025)
# 3  Christian, your storage space if filling up - ...
# 4                    Din order har skickats! 9639607
#
#                          date
# 0  2025-01-27 16:53:45.000000
# 1  2025-01-27 14:15:18.000000
# 2  2025-01-27 14:14:38.000000
# 3  2025-01-27 13:52:51.000000
# 4  2025-01-27 13:16:22.000000

# %%
# Custom query space - modify as needed
custom_query = """
SELECT 
    email_id,
    sender,
    subject,
    date,
    category_id
FROM emails 
WHERE sender LIKE '%@%'
ORDER BY date DESC
LIMIT 10
"""

result_df = pd.read_sql(custom_query, connection)
print("Custom Query Results:")
result_df
