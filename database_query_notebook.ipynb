# %% [markdown]
# # Database Query Notebook
#
# This notebook provides a scratchpad for querying the email processing database with Pandas.

# %%
import pandas as pd
import sys
import os

# Add the project root to Python path
sys.path.append(os.getcwd())

from email_processing.database.db_manager import EmailDatabaseManager

# %%
# Initialize database manager
db_manager = EmailDatabaseManager()
connection = db_manager.get_connection()

print(f"Connected to database: {db_manager.db_path}")
# Out:
# Connected to database: data/email_processing.db

# %%
# Merge all database-tables into dataframe

query_email = "SELECT * FROM emails"
emails_df = pd.read_sql(query_email, connection)

query_categorizations = "SELECT * FROM categorizations"
categorizations_df = pd.read_sql(query_categorizations, connection)

query_summaries = "SELECT * FROM summaries"
summaries_df = pd.read_sql(query_summaries, connection)

# %%
pd.set_option("display.max_colwidth", 50)
df = pd.DataFrame()
df = emails_df.merge(
    categorizations_df[["email_id", "ai_reasoning"]],
    on="email_id",
    how="left",
)
df = df.merge(
    summaries_df[["email_id", "purpose", "value_for_recipient", "ai_reasoning"]],
    suffixes=("_cat", "_sum"),
    on="email_id",
    how="left",
)
df.head(10).T
# Out:
#                                                                      0  \
# email_id                                              1990bb498a57e609
# date                                        2025-09-02 18:33:28.000000
# sender                              Netflix <info@account.netflix.com>
# subject                                En ny enhet använder ditt konto
# body_markdown        Kontrollera vem som använder ditt Netflix-kont...
# body_clean           Kontrollera vem som använder ditt Netflix-kont...
# pdf_text
# raw_email            {"id": "1990bb498a57e609", "subject": "En ny e...
# category_id                                                          2
# ai_reasoning_cat     This is a security alert from Netflix about a ...
# purpose                                                            NaN
# value_for_recipient                                                NaN
# ai_reasoning_sum                                                   NaN
#
#                                                                      1  \
# email_id                                              1990bb44ffd9e8bc
# date                                        2025-09-02 18:33:09.000000
# sender                              Tim Ferriss <tim@fourhourbody.com>
# subject              New from Tim — "What Most Has My Attention Rig...
# body_markdown        a {text-decoration: none;} ​ ************ New ...
# body_clean           a {text-decoration: none;} ​ ************ New ...
# pdf_text
# raw_email            {"id": "1990bb44ffd9e8bc", "subject": "New fro...
# category_id                                                          1
# ai_reasoning_cat     This is a newsletter email from Tim Ferriss co...
# purpose              Tim Ferriss is sharing his weekly roundup, whi...
# value_for_recipient  The recipient gains access to a new podcast ep...
# ai_reasoning_sum     The email is a newsletter from Tim Ferriss. Th...
#
#                                                                      2  \
# email_id                                              1990b78f53342fe3
# date                                        2025-09-02 10:28:19.000000
# sender                                     GitHub <noreply@github.com>
# subject              [GitHub] Your Dependabot alerts for the week o...
# body_markdown        Dependabot alerts on GitHub Dependabot alerts ...
# body_clean           Dependabot alerts on GitHub Dependabot alerts ...
# pdf_text
# raw_email            {"id": "1990b78f53342fe3", "subject": "[GitHub...
# category_id                                                          2
# ai_reasoning_cat     This is a security alert email from GitHub abo...
# purpose                                                            NaN
# value_for_recipient                                                NaN
# ai_reasoning_sum                                                   NaN
#
#                                                                      3  \
# email_id                                              1990b4558397f0b4
# date                                        2025-09-02 16:31:56.000000
# sender                                     Temu <temu@orders.temu.com>
# subject              En del av din Temu-beställning har överförts t...
# body_markdown        \---------------------------------------------...
# body_clean           \---------------------------------------------...
# pdf_text
# raw_email            {"id": "1990b4558397f0b4", "subject": "En del ...
# category_id                                                          1
# ai_reasoning_cat     This is a shipping notification email from Tem...
# purpose              The sender, Temu, is informing the recipient t...
# value_for_recipient  The recipient knows their package has cleared ...
# ai_reasoning_sum     The email confirms a package is with PostNord ...
#
#                                                                      4  \
# email_id                                              1990b1a132ca27f0
# date                                        2025-09-02 15:44:37.000000
# sender                        LinkedIn <messages-noreply@linkedin.com>
# subject              2 new Chief Product Officer openings at Amendo...
# body_markdown        \---------------------------------------- Hiri...
# body_clean           \---------------------------------------- Hiri...
# pdf_text
# raw_email            {"id": "1990b1a132ca27f0", "subject": "2 new C...
# category_id                                                          1
# ai_reasoning_cat     This is a promotional email from LinkedIn noti...
# purpose              LinkedIn sent this email to inform the recipie...
# value_for_recipient  The email provides the recipient with informat...
# ai_reasoning_sum     The email's subject and body clearly indicate ...
#
#                                                                      5  \
# email_id                                              1990b180383e7498
# date                                        2025-09-02 17:42:26.000000
# sender                                 "H&M" <membership@email.hm.com>
# subject                                         Uppdatering av villkor
# body_markdown        Open the email in browser on following link\nh...
# body_clean           Open the email in browser on following link\nh...
# pdf_text
# raw_email            {"id": "1990b180383e7498", "subject": "Uppdate...
# category_id                                                          1
# ai_reasoning_cat     This is a notification email from H&M about te...
# purpose              The sender, H&M, is sending an update to their...
# value_for_recipient  The recipient is informed about changes to the...
# ai_reasoning_sum     The email subject indicates an update to terms...
#
#                                                                      6  \
# email_id                                              1990af6275cda803
# date                                        2025-09-02 15:05:27.000000
# sender               Bagaren och Kocken <no-reply@bagarenochkocken.se>
# subject                      Lagerrensning! Fynda över 1600 produkter
# body_markdown        Belysningsveckor | 15% på utvalt från Sage Ple...
# body_clean           Belysningsveckor | 15% på utvalt från Sage Ple...
# pdf_text
# raw_email            {"id": "1990af6275cda803", "subject": "Lagerre...
# category_id                                                          1
# ai_reasoning_cat     This is clearly a promotional email about a cl...
# purpose              The sender, Bagaren och Kocken, is promoting a...
# value_for_recipient  The email informs the recipient about potentia...
# ai_reasoning_sum     The email subject indicates a clearance sale, ...
#
#                                                                      7  \
# email_id                                              1990aee2541f2915
# date                                        2025-09-02 14:56:42.000000
# sender                      Elite Hotels Rewards <newsletter@elite.se>
# subject                             Skäm bort dig med en höstweekend 🍁
# body_markdown        Upp till 25 % rabatt för medlemmar [WEBBVERSIO...
# body_clean           Upp till 25 % rabatt för medlemmar [WEBBVERSIO...
# pdf_text
# raw_email            {"id": "1990aee2541f2915", "subject": "Sk\u00e...
# category_id                                                          1
# ai_reasoning_cat     This is a promotional newsletter from Elite Ho...
# purpose              The sender, Elite Hotels Rewards, is promoting...
# value_for_recipient  The recipient can save up to 25% on hotel stay...
# ai_reasoning_sum     The email promotes discounts on hotel stays fo...
#
#                                                                      8  \
# email_id                                              1990aca8c0a2ad1c
# date                                        2025-09-02 14:15:55.000000
# sender                                 GAFFA Sweden <noreply@gaffa.se>
# subject                              Får vi nytt från Håkan Hellström?
# body_markdown        Hello, You have received a newsletter from GAF...
# body_clean           Hello, You have received a newsletter from GAF...
# pdf_text
# raw_email            {"id": "1990aca8c0a2ad1c", "subject": "F\u00e5...
# category_id                                                          1
# ai_reasoning_cat     This is clearly a newsletter email from GAFFA ...
# purpose              The sender, GAFFA Sweden, sent a newsletter to...
# value_for_recipient  The recipient can stay updated on music news a...
# ai_reasoning_sum     The email is a newsletter from GAFFA Sweden. T...
#
#                                                                      9
# email_id                                              1990ab7d6d290b51
# date                                        2025-09-02 13:57:23.000000
# sender                                   SEB no-reply <noreply@seb.se>
# subject                                    Din ansökan om att bli kund
# body_markdown                                                     \n\n
# body_clean
# pdf_text
# raw_email            {"id": "1990ab7d6d290b51", "subject": "Din ans...
# category_id                                                          1
# ai_reasoning_cat     This appears to be an automated notification e...
# purpose              The sender, SEB, is confirming they received a...
# value_for_recipient  The recipient knows their application was rece...
# ai_reasoning_sum     The subject indicates an application confirmat...

# %%
import textwrap

pd.set_option("display.max_colwidth", 50)
# Fetch all emails from the emails table
query = "SELECT * FROM categorizations"
categorizations_df = pd.read_sql(query, connection)


# def wrap_column(categorizations_df, col, width=80):
#     categorizations_df[col] = categorizations_df[col].apply(
#         lambda x: "\n".join(textwrap.wrap(str(x), width))
#     )
#     return categorizations_df


# # Usage:
# categorizations_df = wrap_column(categorizations_df, "ai_reasoning", width=80)


print(f"Fetched {len(categorizations_df)} categorizations from database")
categorizations_df.sort_values(by="created_at", ascending=True)[
    ["email_id", "ai_reasoning"]
].head(20)
# Out:
# Fetched 30 categorizations from database
#             email_id                                       ai_reasoning
# 0   1990bb498a57e609  This is a security alert from Netflix about a ...
# 1   1990bb44ffd9e8bc  This is a newsletter email from Tim Ferriss co...
# 2   1990b78f53342fe3  This is a security alert email from GitHub abo...
# 3   1990b4558397f0b4  This is a shipping notification email from Tem...
# 4   1990b1a132ca27f0  This is a promotional email from LinkedIn noti...
# 5   1990b180383e7498  This is a notification email from H&M about te...
# 6   1990af6275cda803  This is clearly a promotional email about a cl...
# 7   1990aee2541f2915  This is a promotional newsletter from Elite Ho...
# 8   1990aca8c0a2ad1c  This is clearly a newsletter email from GAFFA ...
# 9   1990ab7d6d290b51  This appears to be an automated notification e...
# 10  1990ab638a16eb90  This is a payment confirmation email from Qlir...
# 11  1990aabe3b75242f  This is a LinkedIn job recommendation email co...
# 12  1990a8f4b7af9b33  This appears to be an automated notification e...
# 13  1990a859fd71266f  This is a notification email from Gjensidige I...
# 14  1990a7ba8d20fa25  This is an automated order status notification...
# 15  1990a529b9c49232  This is a promotional email from Adidas advert...
# 16  1990a3daccdac2c3  This is an automated LinkedIn job alert notifi...
# 17  1990a3a5afbbf56d  This is a marketing email forwarded through a ...
# 18  1990a38ec225b039  This is a login authentication email containin...
# 19  1990a0093a32b84e  This is an automated notification email from E...

# %%
# Fetch all emails from the emails table
query = "SELECT * FROM emails"
emails_df = pd.read_sql(query, connection)

print(f"Fetched {len(emails_df)} emails from database")
emails_df.sort_values(by="date", ascending=True)
# Out:
# Fetched 30 emails from database
#             email_id                        date  \
# 20  19909fd14a5e7e55  2025-09-02 04:31:58.000000
# 29  19908d4ff85b69c8  2025-09-02 05:10:00.000000
# 15  1990a529b9c49232  2025-09-02 06:06:46.000000
# 28  19909627cf61b885  2025-09-02 07:44:31.000000
# 27  19909729c36593a3  2025-09-02 08:02:09.000000
# 26  1990973ec9db7b70  2025-09-02 08:03:35.000000
# 25  199098fd4a49e8f9  2025-09-02 08:34:04.000000
# 24  19909ab95b5321f6  2025-09-02 09:04:21.000000
# 23  19909d0187d04649  2025-09-02 09:44:15.000000
# 22  19909d822e79e105  2025-09-02 09:53:01.000000
# 21  19909f26c49da46c  2025-09-02 10:21:46.000000
# 2   1990b78f53342fe3  2025-09-02 10:28:19.000000
# 19  1990a0093a32b84e  2025-09-02 10:37:13.000000
# 18  1990a38ec225b039  2025-09-02 11:38:46.000000
# 17  1990a3a5afbbf56d  2025-09-02 11:40:20.000000
# 16  1990a3daccdac2c3  2025-09-02 11:43:55.000000
# 14  1990a7ba8d20fa25  2025-09-02 12:51:40.000000
# 12  1990a8f4b7af9b33  2025-09-02 13:13:06.000000
# 11  1990aabe3b75242f  2025-09-02 13:44:20.000000
# 10  1990ab638a16eb90  2025-09-02 13:55:37.000000
# 9   1990ab7d6d290b51  2025-09-02 13:57:23.000000
# 8   1990aca8c0a2ad1c  2025-09-02 14:15:55.000000
# 7   1990aee2541f2915  2025-09-02 14:56:42.000000
# 13  1990a859fd71266f  2025-09-02 15:02:31.000000
# 6   1990af6275cda803  2025-09-02 15:05:27.000000
# 4   1990b1a132ca27f0  2025-09-02 15:44:37.000000
# 3   1990b4558397f0b4  2025-09-02 16:31:56.000000
# 5   1990b180383e7498  2025-09-02 17:42:26.000000
# 1   1990bb44ffd9e8bc  2025-09-02 18:33:09.000000
# 0   1990bb498a57e609  2025-09-02 18:33:28.000000
#
#                                                sender  \
# 20               "Outside+" <membership@outside.plus>
# 29           Medium Daily Digest <noreply@medium.com>
# 15                 adidas <adidas@se-news.adidas.com>
# 28  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 27           GolfStar Sverige <no-reply@sweetspot.io>
# 26           GolfStar Sverige <no-reply@sweetspot.io>
# 25      Care of Carl <no-reply@emails.careofcarl.com>
# 24              LinkedIn <jobs-listings@linkedin.com>
# 23  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 22           GolfStar Sverige <no-reply@sweetspot.io>
# 21                      TLDR <dan@tldrnewsletter.com>
# 2                         GitHub <noreply@github.com>
# 19  Ework Verama Notification <no-reply.verama@ewo...
# 18  Anthropic <no-reply-Op9BoCKL2da91jn94bbI-g@mai...
# 17            "noreply@ascio.com" <noreply@ascio.com>
# 16  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 14                        Temu <temu@orders.temu.com>
# 12             <RACcorporateonboardingnoreply@seb.se>
# 11              LinkedIn <jobs-listings@linkedin.com>
# 10                        Qliro <noreply@e.qliro.com>
# 9                       SEB no-reply <noreply@seb.se>
# 8                     GAFFA Sweden <noreply@gaffa.se>
# 7          Elite Hotels Rewards <newsletter@elite.se>
# 13                             no-reply@gjensidige.se
# 6   Bagaren och Kocken <no-reply@bagarenochkocken.se>
# 4            LinkedIn <messages-noreply@linkedin.com>
# 3                         Temu <temu@orders.temu.com>
# 5                     "H&M" <membership@email.hm.com>
# 1                  Tim Ferriss <tim@fourhourbody.com>
# 0                  Netflix <info@account.netflix.com>
#
#                                               subject  \
# 20  Top 5 Reads: How Two Hikers Fought Off Bears—A...
# 29  MindsDB: The Only MCP Server You’ll Ever Need ...
# 15           Släpptes nyss: Teamgeist & Adilenium 4.0
# 28  “consultant”: KPMG Sweden - Management Consult...
# 27                        Avbokning: GolfStar Sverige
# 26                                      Återbetalning
# 25  Upptäck Outdoor: Premiumsortiment för naturens...
# 24  Companies like Forefront Amplify and others in...
# 23  “project manager”: Persona - Project Manager (...
# 22              Bokningsbekräftelse: GolfStar Sverige
# 21  Samsung AI glasses 👓, trillion dollar biotechs...
# 2   [GitHub] Your Dependabot alerts for the week o...
# 19                 New jobs published in your country
# 18  Secure link to log in to Anthropic Console |  ...
# 17  Create Brand for Your Company Through Logo And...
# 16  “management consultant”: KPMG Sweden - Managem...
# 14  En del av din Temu-beställning har överförts t...
# 12       Angående din ansökan om att bli företagskund
# 11  You may be a fit for Kognity’s Chief Product O...
# 10       Bekräftelse på din betalning | Bangerhead.se
# 9                         Din ansökan om att bli kund
# 8                   Får vi nytt från Håkan Hellström?
# 7                  Skäm bort dig med en höstweekend 🍁
# 13  Du har fått ett meddelande från Gjensidige För...
# 6           Lagerrensning! Fynda över 1600 produkter
# 4   2 new Chief Product Officer openings at Amendo...
# 3   En del av din Temu-beställning har överförts t...
# 5                              Uppdatering av villkor
# 1   New from Tim — "What Most Has My Attention Rig...
# 0                     En ny enhet använder ditt konto
#
#                                         body_markdown  \
# 20  Plus, the most-searched National Park accordin...
# 29  Stories for Christian Wahlström @christian.wah...
# 15  adidas Godkänd streetlook\nhttps://click.link....
# 28  Your job alert for consultant in Greater Stock...
# 27  |  \n---  \n  \n|  Hej Christian  \n---  \nDin...
# 26  |  |  |    \n---  \n  \n## Återbetalning  \n  ...
# 25  [https://cdn.eu1.exponea.com/care-of-carl-\nli...
# 24  Hiring in your network Explore relevant jobs t...
# 23  Your job alert for project manager in Greater ...
# 22  |  \n---  \n  \n|  Hej Christian  \n---  \nDin...
# 21  Samsung is set to unveil three new devices at ...
# 2   Dependabot alerts on GitHub Dependabot alerts ...
# 19  Hi Christian, 11 new jobs from your country ju...
# 18  |  \n---  \n  \n| |   \n---  \nLet’s get you s...
# 17  Dear Registrant,\n\nAs part of our requirement...
# 16  Your job alert for management consultant in St...
# 14  \---------------------------------------------...
# 12                                               \n\n
# 11  Top job picks for you:\nhttps://www.linkedin.c...
# 10  Se alla köp och betalningar i appen ͏‌ ͏‌ ͏‌ ͏...
# 9                                                \n\n
# 8   Hello, You have received a newsletter from GAF...
# 7   Upp till 25 % rabatt för medlemmar [WEBBVERSIO...
# 13  Hej Christian Wahlstr�m Du har f�tt ny post av...
# 6   Belysningsveckor | 15% på utvalt från Sage Ple...
# 4   \---------------------------------------- Hiri...
# 3   \---------------------------------------------...
# 5   Open the email in browser on following link\nh...
# 1   a {text-decoration: none;} ​ ************ New ...
# 0   Kontrollera vem som använder ditt Netflix-kont...
#
#                                            body_clean pdf_text  \
# 20  Plus, the most-searched National Park accordin...
# 29  Stories for Christian Wahlström @christian.wah...
# 15  adidas Godkänd streetlook\nhttps://click.link....
# 28  Your job alert for consultant in Greater Stock...
# 27  |\n---\n|  Hej Christian\n---\nDin bokning på ...
# 26  |  |  |\n---\n## Återbetalning\n|  |  **Transa...
# 25  [https://cdn.eu1.exponea.com/care-of-carl-\nli...
# 24  Hiring in your network Explore relevant jobs t...
# 23  Your job alert for project manager in Greater ...
# 22  |\n---\n|  Hej Christian\n---\nDin bokning på ...
# 21  Samsung is set to unveil three new devices at ...
# 2   Dependabot alerts on GitHub Dependabot alerts ...
# 19  Hi Christian, 11 new jobs from your country ju...
# 18  |\n---\n| |\n---\nLet’s get you signed in\nSig...
# 17  Dear Registrant,\nAs part of our requirement t...
# 16  Your job alert for management consultant in St...
# 14  \---------------------------------------------...
# 12
# 11  Top job picks for you:\nhttps://www.linkedin.c...
# 10  Se alla köp och betalningar i appen ͏‌ ͏‌ ͏‌ ͏...
# 9
# 8   Hello, You have received a newsletter from GAF...
# 7   Upp till 25 % rabatt för medlemmar [WEBBVERSIO...
# 13  Hej Christian Wahlstr�m Du har f�tt ny post av...
# 6   Belysningsveckor | 15% på utvalt från Sage Ple...
# 4   \---------------------------------------- Hiri...
# 3   \---------------------------------------------...
# 5   Open the email in browser on following link\nh...
# 1   a {text-decoration: none;} ​ ************ New ...
# 0   Kontrollera vem som använder ditt Netflix-kont...
#
#                                             raw_email  category_id
# 20  {"id": "19909fd14a5e7e55", "subject": "Top 5 R...            1
# 29  {"id": "19908d4ff85b69c8", "subject": "MindsDB...            1
# 15  {"id": "1990a529b9c49232", "subject": "Sl\u00e...            1
# 28  {"id": "19909627cf61b885", "subject": "\u201cc...            1
# 27  {"id": "19909729c36593a3", "subject": "Avbokni...            1
# 26  {"id": "1990973ec9db7b70", "subject": "\u00c5t...            1
# 25  {"id": "199098fd4a49e8f9", "subject": "Uppt\u0...            1
# 24  {"id": "19909ab95b5321f6", "subject": "Compani...            1
# 23  {"id": "19909d0187d04649", "subject": "\u201cp...            1
# 22  {"id": "19909d822e79e105", "subject": "Bokning...            1
# 21  {"id": "19909f26c49da46c", "subject": "Samsung...            1
# 2   {"id": "1990b78f53342fe3", "subject": "[GitHub...            2
# 19  {"id": "1990a0093a32b84e", "subject": "New job...            1
# 18  {"id": "1990a38ec225b039", "subject": "Secure ...            2
# 17  {"id": "1990a3a5afbbf56d", "subject": "Create ...            1
# 16  {"id": "1990a3daccdac2c3", "subject": "\u201cm...            1
# 14  {"id": "1990a7ba8d20fa25", "subject": "En del ...            1
# 12  {"id": "1990a8f4b7af9b33", "subject": "Ang\u00...            1
# 11  {"id": "1990aabe3b75242f", "subject": "You may...            1
# 10  {"id": "1990ab638a16eb90", "subject": "Bekr\u0...            1
# 9   {"id": "1990ab7d6d290b51", "subject": "Din ans...            1
# 8   {"id": "1990aca8c0a2ad1c", "subject": "F\u00e5...            1
# 7   {"id": "1990aee2541f2915", "subject": "Sk\u00e...            1
# 13  {"id": "1990a859fd71266f", "subject": "Du har ...            1
# 6   {"id": "1990af6275cda803", "subject": "Lagerre...            1
# 4   {"id": "1990b1a132ca27f0", "subject": "2 new C...            1
# 3   {"id": "1990b4558397f0b4", "subject": "En del ...            1
# 5   {"id": "1990b180383e7498", "subject": "Uppdate...            1
# 1   {"id": "1990bb44ffd9e8bc", "subject": "New fro...            1
# 0   {"id": "1990bb498a57e609", "subject": "En ny e...            2

# %%
mask = emails_df["date"] > "2023-01-01"
emails_df[mask][["date", "sender", "subject", "body_clean"]].head(20)
# Out:
#                           date  \
# 0   2025-09-02 18:33:28.000000
# 1   2025-09-02 18:33:09.000000
# 2   2025-09-02 10:28:19.000000
# 3   2025-09-02 16:31:56.000000
# 4   2025-09-02 15:44:37.000000
# 5   2025-09-02 17:42:26.000000
# 6   2025-09-02 15:05:27.000000
# 7   2025-09-02 14:56:42.000000
# 8   2025-09-02 14:15:55.000000
# 9   2025-09-02 13:57:23.000000
# 10  2025-09-02 13:55:37.000000
# 11  2025-09-02 13:44:20.000000
# 12  2025-09-02 13:13:06.000000
# 13  2025-09-02 15:02:31.000000
# 14  2025-09-02 12:51:40.000000
# 15  2025-09-02 06:06:46.000000
# 16  2025-09-02 11:43:55.000000
# 17  2025-09-02 11:40:20.000000
# 18  2025-09-02 11:38:46.000000
# 19  2025-09-02 10:37:13.000000
#
#                                                sender  \
# 0                  Netflix <info@account.netflix.com>
# 1                  Tim Ferriss <tim@fourhourbody.com>
# 2                         GitHub <noreply@github.com>
# 3                         Temu <temu@orders.temu.com>
# 4            LinkedIn <messages-noreply@linkedin.com>
# 5                     "H&M" <membership@email.hm.com>
# 6   Bagaren och Kocken <no-reply@bagarenochkocken.se>
# 7          Elite Hotels Rewards <newsletter@elite.se>
# 8                     GAFFA Sweden <noreply@gaffa.se>
# 9                       SEB no-reply <noreply@seb.se>
# 10                        Qliro <noreply@e.qliro.com>
# 11              LinkedIn <jobs-listings@linkedin.com>
# 12             <RACcorporateonboardingnoreply@seb.se>
# 13                             no-reply@gjensidige.se
# 14                        Temu <temu@orders.temu.com>
# 15                 adidas <adidas@se-news.adidas.com>
# 16  LinkedIn Job Alerts <jobalerts-noreply@linkedi...
# 17            "noreply@ascio.com" <noreply@ascio.com>
# 18  Anthropic <no-reply-Op9BoCKL2da91jn94bbI-g@mai...
# 19  Ework Verama Notification <no-reply.verama@ewo...
#
#                                               subject  \
# 0                     En ny enhet använder ditt konto
# 1   New from Tim — "What Most Has My Attention Rig...
# 2   [GitHub] Your Dependabot alerts for the week o...
# 3   En del av din Temu-beställning har överförts t...
# 4   2 new Chief Product Officer openings at Amendo...
# 5                              Uppdatering av villkor
# 6           Lagerrensning! Fynda över 1600 produkter
# 7                  Skäm bort dig med en höstweekend 🍁
# 8                   Får vi nytt från Håkan Hellström?
# 9                         Din ansökan om att bli kund
# 10       Bekräftelse på din betalning | Bangerhead.se
# 11  You may be a fit for Kognity’s Chief Product O...
# 12       Angående din ansökan om att bli företagskund
# 13  Du har fått ett meddelande från Gjensidige För...
# 14  En del av din Temu-beställning har överförts t...
# 15           Släpptes nyss: Teamgeist & Adilenium 4.0
# 16  “management consultant”: KPMG Sweden - Managem...
# 17  Create Brand for Your Company Through Logo And...
# 18  Secure link to log in to Anthropic Console |  ...
# 19                 New jobs published in your country
#
#                                            body_clean
# 0   Kontrollera vem som använder ditt Netflix-kont...
# 1   a {text-decoration: none;} ​ ************ New ...
# 2   Dependabot alerts on GitHub Dependabot alerts ...
# 3   \---------------------------------------------...
# 4   \---------------------------------------- Hiri...
# 5   Open the email in browser on following link\nh...
# 6   Belysningsveckor | 15% på utvalt från Sage Ple...
# 7   Upp till 25 % rabatt för medlemmar [WEBBVERSIO...
# 8   Hello, You have received a newsletter from GAF...
# 9
# 10  Se alla köp och betalningar i appen ͏‌ ͏‌ ͏‌ ͏...
# 11  Top job picks for you:\nhttps://www.linkedin.c...
# 12
# 13  Hej Christian Wahlstr�m Du har f�tt ny post av...
# 14  \---------------------------------------------...
# 15  adidas Godkänd streetlook\nhttps://click.link....
# 16  Your job alert for management consultant in St...
# 17  Dear Registrant,\nAs part of our requirement t...
# 18  |\n---\n| |\n---\nLet’s get you signed in\nSig...
# 19  Hi Christian, 11 new jobs from your country ju...

# %%
# Example: Query specific columns only
query = "SELECT email_id, sender, subject, date FROM emails"
emails_summary_df = pd.read_sql(query, connection)

print("Email Summary:")
emails_summary_df.head()
# Out:
# Email Summary:
#            email_id                                    sender  \
# 0  1990bb498a57e609        Netflix <info@account.netflix.com>
# 1  1990bb44ffd9e8bc        Tim Ferriss <tim@fourhourbody.com>
# 2  1990b78f53342fe3               GitHub <noreply@github.com>
# 3  1990b4558397f0b4               Temu <temu@orders.temu.com>
# 4  1990b1a132ca27f0  LinkedIn <messages-noreply@linkedin.com>
#
#                                              subject  \
# 0                    En ny enhet använder ditt konto
# 1  New from Tim — "What Most Has My Attention Rig...
# 2  [GitHub] Your Dependabot alerts for the week o...
# 3  En del av din Temu-beställning har överförts t...
# 4  2 new Chief Product Officer openings at Amendo...
#
#                          date
# 0  2025-09-02 18:33:28.000000
# 1  2025-09-02 18:33:09.000000
# 2  2025-09-02 10:28:19.000000
# 3  2025-09-02 16:31:56.000000
# 4  2025-09-02 15:44:37.000000

# %%
# Custom query space - modify as needed
custom_query = """
SELECT 
    email_id,
    sender,
    subject,
    date,
    category_id
FROM emails 
WHERE sender LIKE '%@%'
ORDER BY date DESC
LIMIT 10
"""

result_df = pd.read_sql(custom_query, connection)
print("Custom Query Results:")
result_df
# Out:
# Custom Query Results:
#            email_id                                             sender  \
# 0  1990bb498a57e609                 Netflix <info@account.netflix.com>
# 1  1990bb44ffd9e8bc                 Tim Ferriss <tim@fourhourbody.com>
# 2  1990b180383e7498                    "H&M" <membership@email.hm.com>
# 3  1990b4558397f0b4                        Temu <temu@orders.temu.com>
# 4  1990b1a132ca27f0           LinkedIn <messages-noreply@linkedin.com>
# 5  1990af6275cda803  Bagaren och Kocken <no-reply@bagarenochkocken.se>
# 6  1990a859fd71266f                             no-reply@gjensidige.se
# 7  1990aee2541f2915         Elite Hotels Rewards <newsletter@elite.se>
# 8  1990aca8c0a2ad1c                    GAFFA Sweden <noreply@gaffa.se>
# 9  1990ab7d6d290b51                      SEB no-reply <noreply@seb.se>
#
#                                              subject  \
# 0                    En ny enhet använder ditt konto
# 1  New from Tim — "What Most Has My Attention Rig...
# 2                             Uppdatering av villkor
# 3  En del av din Temu-beställning har överförts t...
# 4  2 new Chief Product Officer openings at Amendo...
# 5          Lagerrensning! Fynda över 1600 produkter
# 6  Du har fått ett meddelande från Gjensidige För...
# 7                 Skäm bort dig med en höstweekend 🍁
# 8                  Får vi nytt från Håkan Hellström?
# 9                        Din ansökan om att bli kund
#
#                          date  category_id
# 0  2025-09-02 18:33:28.000000            2
# 1  2025-09-02 18:33:09.000000            1
# 2  2025-09-02 17:42:26.000000            1
# 3  2025-09-02 16:31:56.000000            1
# 4  2025-09-02 15:44:37.000000            1
# 5  2025-09-02 15:05:27.000000            1
# 6  2025-09-02 15:02:31.000000            1
# 7  2025-09-02 14:56:42.000000            1
# 8  2025-09-02 14:15:55.000000            1
# 9  2025-09-02 13:57:23.000000            1
